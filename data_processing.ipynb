992206474789,
891423974548,
420776110437,
420776110437,
905340736710,
994703800039,
905074058304,
420776110437,
992888339352,
998939675059,
996773146613,
992004444422,
971509553544,
905323772444,
919820365190,
992929591700,
375687165227,
998901345044,
994507918219,
491575557168,
899195691855,
572011527705,
789992323232,
555555555555,
358417926828,
996773146613,
998901423000,
998901423001,
375292602623,
890988600781,
628118160211,
998957791000,
893222000920,
420311879456,
898290838771,
995577763773,
789827754952,
992927775971,
992926776597,
996709998199,
905347051048,
905516786884,
905347051048,
905347051048,
789044931746,
788998989898,
789989898989,
905347051048,
998950091516,
891994336611,
998909671910,
201557823773,
899502925512,
898290838771,
572011527705,
998950091516,
998950091516,
998950091516,
891423974548,
789829135110,
992885555111,
992883337036,
777777777777,
380953914719,
919814662322,
381611637904,
996708555014,
994773203716,
899999999999,
572011527705,
971566012096,
971566012096,
375297065352,
992928555255,
789220788773,
992927090081,
955018803,
587287587,
222222225,
954810895,
954801140,
792385417,
954977072,
954897542,
954850490,
647574557,
954898831,
45468456,
96339305,
79218375,
'8ed91993235',
'8ed79822146',
71,
71111111111,
712,
71111111111)

incorrect_phones = pd.Series(incorrect_phones)
date_columns = ['дата создания заявки на покупку/продажу', 'дата закрытия заявки на покупку/продажу', 'дата продажи']

# %%
df = get_table_sql()

# %%
df_work = df.copy()

# %%
def df_types(df, date_cols):
    for col in df.columns:
        print(col)

        if col in date_cols:
            df[col] = df[col].astype(str).apply(lambda x: x.replace('.', '-'))
            df[col] = pd.to_datetime(df[col], dayfirst=True)

        elif col=='дата продажи':
            df[col].loc[df[col]!='0000-00-00'] = pd.to_datetime(df[col])
        
        else:
            df[col] = df[col].astype(pd.StringDtype())



def delete_numbers(df, phones):
    pass

# %%
df_work = df_work.fillna(value=np.nan)

# %%
df_work.head(5)
# Out:
#     Город  Номер заявки на покупку/продажу  \
# 0  Тюмень                         37164813
# 1  Тюмень                         39676358
# 2  Тюмень                         41935235
# 3  Тюмень                         42090534
# 4  Тюмень                         42413414
#
#   дата создания заявки на покупку/продажу  \
# 0                                03-01-23
# 1                                28-04-23
# 2                                09-08-23
# 3                                15-08-23
# 4                                27-08-23
#
#   дата закрытия заявки на покупку/продажу типзаявки на покупку/продажу  \
# 0                                    None            Покупка вторичная
# 1                                    None            Покупка вторичная
# 2                                    None            Покупка вторичная
# 3                                    None            Покупка вторичная
# 4                                    None            Покупка вторичная
#
# ...

# %%
df_work['дата создания заявки на покупку/продажу'] = df_work['дата создания заявки на покупку/продажу'].astype(str).apply(lambda x: x.replace('.', '-'))

# %%
pd.to_datetime(df_work['дата создания заявки на покупку/продажу'])
# Out:
# Город                                       string
# Номер заявки на покупку/продажу             string
# дата создания заявки на покупку/продажу     object
# дата закрытия заявки на покупку/продажу     object
# типзаявки на покупку/продажу                object
# статус заявки                               object
# ФИО клиента                                 object
# Телефон клиента 1                           object
# Телефон клиента 2                           object
# Телефон клиента 3                          float64
# id риэлтора                                  int64
# ФИО риэлтора                                object
# ФИО менеджера                               object
# дата продажи                                object
# dtype: object

# %%
df_types(df_work, date_columns)
# Out:
# Город
# Номер заявки на покупку/продажу
# дата создания заявки на покупку/продажу
# C:\Users\ws-tmn-an-15\AppData\Local\Temp\ipykernel_3728\3312479280.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].loc[df[col].notna()] = pd.to_datetime(df[col], dayfirst=True)
# дата закрытия заявки на покупку/продажу
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ws-tmn-an-15\AppData\Local\Programs\Python\Python39\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# ...
